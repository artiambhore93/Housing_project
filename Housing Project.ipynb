# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df01=pd.read_csv('HousingProject_TESTDATA')

# %%
df01
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %%
df02=pd.read_csv('HousingProject_TRAINDATA')
df02
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
print('Test_Data',df01.shape)
print('Train_Data',df02.shape)
# Out:
# Test_Data (292, 80)
# Train_Data (1168, 81)

# %% [markdown]
# Test data contains 292 rows and 80 columns
# train data contains 1168 rows and 81 columns.

# %% [markdown]
# # Checking for null values:

# %%
df01.isnull()
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0    False       False     False        False    False   False   True
# 1    False       False     False         True    False   False   True
# 2    False       False     False         True    False   False   True
# 3    False       False     False        False    False   False   True
# 4    False       False     False        False    False   False   True
# ..     ...         ...       ...          ...      ...     ...    ...
# 287  False       False     False        False    False   False   True
# 288  False       False     False        False    False   False   True
# 289  False       False     False         True    False   False   True
# 290  False       False     False        False    False   False   True
# 291  False       False     False        False    False   False   True
#
#      LotShape  LandContour  Utilities  ...  ScreenPorch  PoolArea  PoolQC  \
# ...

# %%
df01.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      45
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64

# %%
df01.isnull().sum().sum()
# Out:
# 1407

# %%
df02.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False         True    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False         True    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1163  False       False     False         True    False   False   True
# 1164  False       False     False        False    False   False   True
# 1165  False       False     False        False    False   False   True
# 1166  False       False     False        False    False   False  False
# 1167  False       False     False         True    False   False   True
#
#       LotShape  LandContour  Utilities  ...  PoolArea  PoolQC  Fence  \
# ...

# %%
df02.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df02.isnull().sum().sum()
# Out:
# 5558

# %% [markdown]
# So, Test data (df01) having 1407 null values and Train data (df02) having 5558 null values.

# %%
df01.describe()
# Out:
#                 Id  MSSubClass  LotFrontage        LotArea  OverallQual  \
# count   292.000000  292.000000   247.000000     292.000000   292.000000
# mean    755.955479   57.414384    66.425101   10645.143836     6.078767
# std     442.565228   43.780649    21.726343   13330.669795     1.356147
# min       6.000000   20.000000    21.000000    1526.000000     3.000000
# 25%     377.750000   20.000000    53.500000    7200.000000     5.000000
# 50%     778.000000   50.000000    65.000000    9200.000000     6.000000
# 75%    1152.250000   70.000000    79.000000   11658.750000     7.000000
# max    1456.000000  190.000000   150.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count   292.000000   292.000000    292.000000   291.000000   292.000000  ...
# mean      5.493151  1972.616438   1985.294521   109.171821   439.294521  ...
# std       1.063267    30.447016     20.105792   175.030021   429.559675  ...
# ...

# %%
df02.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1168.000000  1168.000000    954.00000    1168.000000  1168.000000
# mean    724.136130    56.767979     70.98847   10484.749144     6.104452
# std     416.159877    41.940650     24.82875    8957.442311     1.390153
# min       1.000000    20.000000     21.00000    1300.000000     1.000000
# 25%     360.500000    20.000000     60.00000    7621.500000     5.000000
# 50%     714.500000    50.000000     70.00000    9522.500000     6.000000
# 75%    1079.500000    70.000000     80.00000   11515.500000     7.000000
# max    1460.000000   190.000000    313.00000  164660.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1168.000000  1168.000000   1168.000000  1161.000000  1168.000000  ...
# mean      5.595890  1970.930651   1984.758562   102.310078   444.726027  ...
# std       1.124343    30.145255     20.785185   182.595606   462.664785  ...
# ...

# %%
df01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    247 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   Alley          14 non-null     object
#  7   LotShape       292 non-null    object
#  8   LandContour    292 non-null    object
#  9   Utilities      292 non-null    object
#  10  LotConfig      292 non-null    object
#  11  LandSlope      292 non-null    object
#  12  Neighborhood   292 non-null    object
#  13  Condition1     292 non-null    object
#  14  Condition2     292 non-null    object
#  15  BldgType       292 non-null    object
#  16  HouseStyle     292 non-null    object
# ...

# %%
df02.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %% [markdown]
# # Fill the missing values for both "Traning" and "Test" dataset

# %%
# Fill the columns with mean as its continous data

df02["LotFrontage"].fillna(df02["LotFrontage"].mean(), inplace=True)
df02["MasVnrArea"].fillna(df02["MasVnrArea"].mean(), inplace=True)

# %%
# Fill the columns with mode as its categorical data

df02["MasVnrType"].fillna(df02["MasVnrType"].value_counts().index[0], inplace=True)
df02["BsmtQual"].fillna(df02["BsmtQual"].value_counts().index[0], inplace=True)
df02["BsmtCond"].fillna(df02["BsmtCond"].value_counts().index[0], inplace=True)
df02["BsmtExposure"].fillna(df02["BsmtExposure"].value_counts().index[0], inplace=True)
df02["BsmtFinType1"].fillna(df02["BsmtFinType1"].value_counts().index[0], inplace=True)
df02["BsmtFinType2"].fillna(df02["BsmtFinType2"].value_counts().index[0], inplace=True)
df02["FireplaceQu"].fillna(df02["FireplaceQu"].value_counts().index[0], inplace=True)
df02["GarageType"].fillna(df02["GarageType"].value_counts().index[0], inplace=True)
df02["GarageYrBlt"].fillna(df02["GarageYrBlt"].value_counts().index[0], inplace=True)
df02["GarageFinish"].fillna(df02["GarageFinish"].value_counts().index[0], inplace=True)
df02["GarageQual"].fillna(df02["GarageQual"].value_counts().index[0], inplace=True)
df02["GarageCond"].fillna(df02["GarageCond"].value_counts().index[0], inplace=True)

# %%
df02.drop(columns = ["Alley", "PoolQC", "Fence", "MiscFeature"], axis=1, inplace=True)
df01.drop(columns = ["Alley", "PoolQC", "Fence", "MiscFeature"], axis=1, inplace=True)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.ensemble import GradientBoostingRegressor

from sklearn.metrics import mean_squared_error, mean_absolute_error
from statsmodels.stats.outliers_influence import variance_inflation_factor

from sklearn.model_selection import train_test_split
from scipy.stats import zscore
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings("ignore")

# %%
# Plot below can identify the zoning area of the properties / apartments that are up for sale.

plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
ax = sns.countplot("MSZoning", data=df02, hue= "Street", palette="rocket").set(title='Different housing zones') 
plt.show()

# %%
# Plot gives idea on the locality of neughbourhood 

plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
ax = sns.countplot("Neighborhood", data=df02).set(title='Neighbourhood assosiated around the property') 
plt.xticks(rotation=70)
plt.show()

# %%
# Relation between SaleType and SalePrice.

plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
sns.lineplot(data=df02, x="SaleType", y="SalePrice", hue = "YrSold", ci=None).set(title='Sales price based on the sale type of houses')
plt.show()

# %%
# Plot shows us the years when properties were sold the highest.

year_new = df02['YrSold'].astype(str)

plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
sns.lineplot(data=df02, x=year_new, y="SalePrice", ci=None).set(title='Sales price affecting over the year of house')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
ax = sns.countplot("YrSold", data=df02, palette= "magma", 
                   hue="SaleCondition").set(title='How the considtion of house looks like based on the ageing of house') 
plt.show()

# %%
# It appears Warranty Deed seems to be the most sought after payment or purchasing method ,it's clearly in favour of both the parties as and when the duration of built year and sale year increases.

gap_of_sale = df02["YrSold"] - df02["YearBuilt"]

plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
sns.scatterplot(data=df02, x=gap_of_sale, 
                y="SalePrice", hue="SaleType").set(title='Sale price of house baed on sale of year')
plt.show()

# %%
# Below plot shows number of years taken to remodel doesn't realy seem to affect the sale type.

gap_of_model = df02["YearRemodAdd"] - df02["YearBuilt"]

plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
sns.scatterplot(data=df02, x=gap_of_model, 
                y="SalePrice", hue="SaleCondition").set(title='Sale price of house vs gap of year taken to remodel')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
sns.stripplot(data=df02, x="Condition1", 
                y="SalePrice", hue="SaleCondition").set(title='Sale price of house basde on amenities around it')
plt.show()

# %%
# Below plot shows "Waranty Deed" and "New" are favourable throughout the year :

plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
sns.stripplot(data=df02, x="SaleType", 
                y="MoSold", hue="SaleCondition").set(title='Months that have good number of sales based on sale type')
plt.show()

# %%
sns.distplot(df02['SalePrice'], color = 'r')
plt.title('Sale Price Distribution', fontsize = 16)
# Out:
# Text(0.5, 1.0, 'Sale Price Distribution')

# %%
# GarageArea: Size of garage in square feet with respect to Sale Price.

plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
sns.stripplot(data=df02, x="SalePrice", 
                y="GarageArea",  hue="SaleCondition").set(title='Garage Area of sales based on sale price')
plt.show()

# %%
# GarageArea: Size of garage in square feet with respect to saleType

plt.figure(figsize=(12, 6))
sns.set_theme(style="whitegrid")
sns.stripplot(data=df02, x="SaleType", 
                y="GarageArea", hue="SaleCondition").set(title='Garage Area of sales based on sale type')
plt.show()

# %%
# OverallQual: Rates the overall material and finish of the house

plt.scatter(x=df02['OverallQual'], y=df02['SalePrice'], 
            color="orange", linewidths=0.5);
plt.xlabel("OverallQual"); plt.ylabel("SalePrice");

# %%
# Gr Liv Area which represents the living area above ground.

sns.distplot(df02['GrLivArea'], kde=False, 
             color="#172B4D", hist_kws={"alpha": 0.8});
plt.ylabel("Count");

# %%
# The above-ground living area falls approximately between 800 and 1800 ft2

# Relationship between GrLivArea and SalePrice

plt.scatter(x=df02['GrLivArea'], y=df02['SalePrice'], 
            color="orange", edgecolors="#000000", linewidths=0.5);
plt.xlabel("Gr Liv Area"); plt.ylabel("SalePrice");

# %%
#  Relationship between the target variable and the variables that are positively correlated with it.

fig, axes = plt.subplots(1, 4, figsize=(12,6))
fig.subplots_adjust(hspace=0.5, wspace=0.6)
for ax, v in zip(axes.flat, ["YearBuilt", "YearRemodAdd", 
                             "MasVnrArea", "TotalBsmtSF"]):
    sns.distplot(df02[v], kde=False, color= 'Gold', 
                 hist_kws={"alpha": 0.8}, ax=ax)
    ax.set(ylabel="Count");

# %%
fig, axes = plt.subplots(1, 4, figsize=(12,6))
fig.subplots_adjust(hspace=0.5, wspace=0.6)
for ax, v in zip(axes.flat, ["1stFlrSF", "FullBath",
                             "GarageCars", "Fireplaces"]):
    sns.distplot(df02[v], kde=False, color= 'Gold', 
                 hist_kws={"alpha": 0.8}, ax=ax)
    ax.set(ylabel="Count");

# %%
# Rating 

mp = {'Ex':4,'Gd':3,'TA':2,'Fa':1,'Po':0}
df02['ExterQual'] = df02['ExterQual'].map(mp)
df02['ExterCond'] = df02['ExterCond'].map(mp)
df02['HeatingQC'] = df02['HeatingQC'].map(mp)
df02['KitchenQual'] = df02['KitchenQual'].map(mp)

mp = {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'No Basement':0}
df02['BsmtQual'] = df02['BsmtQual'].map(mp)
df02['BsmtCond'] = df02['BsmtCond'].map(mp)
df02['BsmtExposure'] = df02['BsmtExposure'].map(
    {'Gd':4,'Av':3,'Mn':2,'No':1,'No Basement':0})

mp = {'GLQ':6,'ALQ':5,'BLQ':4,'Rec':3,'LwQ':2,'Unf':1,'No Basement':0}
df02['BsmtFinType1'] = df02['BsmtFinType1'].map(mp)
df02['BsmtFinType2'] = df02['BsmtFinType2'].map(mp)

df02['CentralAir'] = df02['CentralAir'].map({'Y':1,'N':0})
df02['Functional'] = df02['Functional'].map(
    {'Typ':7,'Min1':6,'Min2':5,'Mod':4,'Maj1':3,
     'Maj2':2,'Sev':1,'Sal':0})

df02['FireplaceQu'] = df02['FireplaceQu'].map(
    {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'No Fireplace':0})

df02['GarageFinish'] = df02['GarageFinish'].map(
    {'Fin':3,'RFn':2,'Unf':1,'No Garage':0})

df02['GarageQual'] = df02['GarageQual'].map(
    {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'No Garage':0})

df02['GarageCond'] = df02['GarageCond'].map(
    {'Ex':5,'Gd':4,'TA':3,'Fa':2,'Po':1,'No Garage':0})


df02['LandSlope'] = df02['LandSlope'].map(
    {'Sev': 2, 'Mod': 1, 'Gtl': 0})

# %%
# Plot realised that most of the houses where sold in the summer months 6 and 7


df02.groupby(['MoSold','YrSold']).count().plot(kind='line',figsize=(14,22))
plt.xlabel('Selling Count')
plt.title('Times of Selling Houses')
plt.legend(bbox_to_anchor=(1, 1))
plt.show()

# %%
df02.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond',
# ...

# %%
# Using LabelEncoder:

from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
# Encode the training dataset

df02.MSZoning = encoder.fit_transform(df02.MSZoning)
df02.Street = encoder.fit_transform(df02.Street)
df02.LotShape = encoder.fit_transform(df02.LotShape)
df02.LandContour = encoder.fit_transform(df02.LandContour)
df02.Utilities = encoder.fit_transform(df02.Utilities)
df02.LotConfig = encoder.fit_transform(df02.LotConfig)
df02.LandSlope = encoder.fit_transform(df02.LandSlope)
df02.Neighborhood = encoder.fit_transform(df02.Neighborhood)
df02.Condition1 = encoder.fit_transform(df02.Condition1)
df02.Condition2 = encoder.fit_transform(df02.Condition2)
df02.BldgType = encoder.fit_transform(df02.BldgType)
df02.HouseStyle = encoder.fit_transform(df02.HouseStyle)
df02.RoofStyle = encoder.fit_transform(df02.RoofStyle)
df02.RoofMatl = encoder.fit_transform(df02.RoofMatl)
df02.Exterior1st = encoder.fit_transform(df02.Exterior1st)
df02.Exterior2nd = encoder.fit_transform(df02.Exterior2nd)
df02.MasVnrType = encoder.fit_transform(df02.MasVnrType)
df02.ExterQual = encoder.fit_transform(df02.ExterQual)
df02.ExterCond = encoder.fit_transform(df02.ExterCond)
df02.Foundation = encoder.fit_transform(df02.Foundation)
df02.BsmtQual = encoder.fit_transform(df02.BsmtQual)
df02.BsmtCond = encoder.fit_transform(df02.BsmtCond)
df02.BsmtExposure = encoder.fit_transform(df02.BsmtExposure)
df02.BsmtFinType1 = encoder.fit_transform(df02.BsmtFinType1)
df02.BsmtFinType2 = encoder.fit_transform(df02.BsmtFinType2)
df02.Heating = encoder.fit_transform(df02.Heating)
df02.HeatingQC = encoder.fit_transform(df02.HeatingQC)
df02.CentralAir = encoder.fit_transform(df02.CentralAir)
df02.Electrical = encoder.fit_transform(df02.Electrical)
df02.KitchenQual = encoder.fit_transform(df02.KitchenQual)
df02.Functional = encoder.fit_transform(df02.Functional)
df02.FireplaceQu = encoder.fit_transform(df02.FireplaceQu)
df02.GarageType = encoder.fit_transform(df02.GarageType)
df02.GarageFinish = encoder.fit_transform(df02.GarageFinish)
df02.GarageQual = encoder.fit_transform(df02.GarageQual)
df02.GarageCond = encoder.fit_transform(df02.GarageCond)
df02.SaleType = encoder.fit_transform(df02.SaleType)
df02.SaleCondition = encoder.fit_transform(df02.SaleCondition)
df02.PavedDrive = encoder.fit_transform(df02.PavedDrive)

# %%
df02.head()
# Out:
#     Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0  127         120         3     70.98847     4928       1         0
# 1  889          20         3     95.00000    15865       1         0
# 2  793          60         3     92.00000     9920       1         0
# 3  110          20         3    105.00000    11751       1         0
# 4  422          20         3     70.98847    16635       1         0
#
#    LandContour  Utilities  LotConfig  ...  EnclosedPorch  3SsnPorch  \
# 0            3          0          4  ...              0          0
# 1            3          0          4  ...              0          0
# 2            3          0          1  ...              0          0
# 3            3          0          4  ...              0          0
# 4            3          0          2  ...              0          0
#
#    ScreenPorch  PoolArea  MiscVal  MoSold  YrSold  SaleType  SaleCondition  \
# ...

# %%
# Distribution of all the columns in the dataset:

# let us now see the distribution of the "Train dataset"

plt.figure(figsize=(20,25), facecolor="white")
plotnumber = 1

for column in df02:
    if plotnumber <=77:
        ax = plt.subplot(8,8, plotnumber)
        sns.distplot(df02[column])
        plt.xlabel(column, fontsize=20)
    plotnumber+=1
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16484/1136243741.py in <module>
#       8 for column in df02:
#       9     if plotnumber <=77:
# ---> 10         ax = plt.subplot(8,8, plotnumber)
#      11         sns.distplot(df02[column])
#      12         plt.xlabel(column, fontsize=20)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# ~\anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
#     652                 if num < 1 or num > rows*cols:
# --> 653                     raise ValueError(
# ...

# %%
corelation=abs(df02.corr()['SalePrice']) >= 0.4
corelation[corelation==True]
# Out:
# OverallQual     True
# YearBuilt       True
# YearRemodAdd    True
# MasVnrArea      True
# ExterQual       True
# BsmtQual        True
# TotalBsmtSF     True
# HeatingQC       True
# 1stFlrSF        True
# GrLivArea       True
# FullBath        True
# KitchenQual     True
# TotRmsAbvGrd    True
# Fireplaces      True
# GarageFinish    True
# GarageCars      True
# GarageArea      True
# SalePrice       True
# Name: SalePrice, dtype: bool

# %%
df02=df02[corelation.index[corelation]]
corelation=corelation.drop(['SalePrice'])
df01=df01[corelation.index[corelation]]

# %%
df01.head()
# Out:
#    OverallQual  YearBuilt  YearRemodAdd  MasVnrArea ExterQual BsmtQual  \
# 0            9       2005          2006       200.0        Gd       Ex
# 1            8       1984          1984         0.0        Gd       Gd
# 2            8       2001          2001         0.0        Gd       Gd
# 3            7       1941          1950         0.0        TA       TA
# 4            6       2007          2007        74.0        Gd       Gd
#
#    TotalBsmtSF HeatingQC  1stFlrSF  GrLivArea  FullBath KitchenQual  \
# 0         1922        Ex      1922       1922         2          Gd
# 1         1220        Gd      1360       1360         1          Gd
# 2         1753        Ex      1788       1788         2          Ex
# 3          704        Ex       860       1564         1          Fa
# 4          894        Ex       894       1933         2          Gd
#
#    TotRmsAbvGrd  Fireplaces GarageFinish  GarageCars  GarageArea
# ...

# %%
# train dataset with featurs only
x = df02.drop(columns = ["SalePrice"], axis=1)

y = df02["SalePrice"]

# test dataset with featurs only
x1 = df01

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.30, random_state = 200)

# %% [markdown]
# # KNN:

# %%
from sklearn.neighbors import KNeighborsRegressor

k_neigh = KNeighborsRegressor()
k_neigh.fit(x_train,y_train)

y_pred = k_neigh.predict(x_test)

print("Adjusted R2 squared : ",k_neigh.score(x_train,y_train))
print("Mean Absolute Error (MAE): ", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE): ",mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error (RMSE): ",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Adjusted R2 squared :  0.8667901832681217
# Mean Absolute Error (MAE):  23323.041025641025
# Mean Squared Error (MSE):  1683800580.468718
# Root Mean Squared Error (RMSE):  41034.13920711287

# %% [markdown]
# # DTR:

# %%
from sklearn.tree import DecisionTreeRegressor

dt_reg = DecisionTreeRegressor()
dt_reg.fit(x_train,y_train)

y_pred = dt_reg.predict(x_test)

print("Adjusted R2 squared : ",dt_reg.score(x_train,y_train))
print("Mean Absolute Error (MAE): ", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE): ",mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error (RMSE): ",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Adjusted R2 squared :  1.0
# Mean Absolute Error (MAE):  29726.11396011396
# Mean Squared Error (MSE):  2167883538.7236466
# Root Mean Squared Error (RMSE):  46560.53628045586

# %% [markdown]
# # RFR:

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor()
rf_reg.fit(x_train,y_train)

y_pred = rf_reg.predict(x_test)

print("Adjusted R2 squared : ",rf_reg.score(x_train,y_train))
print("Mean Absolute Error (MAE): ", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE): ",mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error (RMSE): ",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Adjusted R2 squared :  0.9756856910367635
# Mean Absolute Error (MAE):  21662.56547008547
# Mean Squared Error (MSE):  1463886499.469246
# Root Mean Squared Error (RMSE):  38260.769718724245

# %% [markdown]
# # ETR:

# %%
from sklearn.ensemble import ExtraTreesRegressor

extra_reg = ExtraTreesRegressor()
extra_reg.fit(x_train,y_train)

y_pred = extra_reg.predict(x_test)

print("Adjusted R2 squared : ",extra_reg.score(x_train,y_train))
print("Mean Absolute Error (MAE): ", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE): ",mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error (RMSE): ",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Adjusted R2 squared :  1.0
# Mean Absolute Error (MAE):  22482.002478632483
# Mean Squared Error (MSE):  1584047891.1128936
# Root Mean Squared Error (RMSE):  39800.09913446063

# %%
from sklearn.model_selection import GridSearchCV
from pprint import pprint
pprint(rf_reg.get_params())
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
rf_reg_tuned = RandomForestRegressor(n_jobs=1 )
rf_reg_tuned.fit(x_train,y_train)
rf_reg_tuned_ypred = rf_reg_tuned.predict(x_test)
r2_score_rf_reg_tuned = r2_score(y_test,rf_reg_tuned_ypred)

print("Adjusted R2 squared : ",rf_reg.score(x_train,y_train))
print("Mean Absolute Error (MAE): ", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE): ",mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error (RMSE): ",np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# Adjusted R2 squared :  0.9756856910367635
# Mean Absolute Error (MAE):  22482.002478632483
# Mean Squared Error (MSE):  1584047891.1128936
# Root Mean Squared Error (RMSE):  39800.09913446063

# %%
import numpy as np
from sklearn.decomposition import PCA

# %%
pca = PCA().fit(x)
plt.rcParams["figure.figsize"] = (20,10)

fig, ax = plt.subplots()

y = np.cumsum(pca.explained_variance_ratio_)

plt.ylim(0.0,1.1)
plt.plot(y, marker='o', linestyle='--', color='b')

plt.xlabel('Number of Components')
plt.ylabel('Cumulative variance (%)')
plt.title('The number of components needed to explain variance')

plt.axhline(y=0.95, color='r', linestyle='-')
plt.text(0.5, 0.85, '95% cut-off threshold', color = 'red', fontsize=16)

ax.grid(axis='x')
plt.show()

# %%
import joblib
joblib.dump(rf_reg_tuned,"Housing_Pred.pkl")
# Out:
# ['Housing_Pred.pkl']

# %%
model = joblib.load("Housing_Pred.pkl")

prediction = model.predict(x_test)

prediction=pd.DataFrame(prediction)
prediction
# Out:
#              0
# 0    118786.16
# 1    155695.24
# 2    222500.10
# 3    194214.77
# 4    280763.24
# ..         ...
# 346  134296.20
# 347   89534.93
# 348  302932.87
# 349  215098.58
# 350  319634.11
#
# [351 rows x 1 columns]
